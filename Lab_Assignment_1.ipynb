# %% [markdown]
# <a href="https://colab.research.google.com/github/TamimCSE53/Simulation-Modeling-Lab/blob/main/Lab_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-4196390475.py in <cell line: 0>()
#       1 import numpy as nu
# ----> 2 from sympy import matrix
#       3 import matplotlib.pyplot as mu
#       4 import seaborn as su
#       5
#
# ImportError: cannot import name 'matrix' from 'sympy' (/usr/local/lib/python3.12/dist-packages/sympy/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
